# %%
import csv, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns, matplotlib as mpl

# %%
with open('scrapedprices.csv','r') as f:
    reader = csv.reader(f)
    df = pd.DataFrame(reader)
    
df.columns = df.iloc[0] #Set column names
df = df[1:]
df['price'] = pd.to_numeric(df['price'])
df.head()
# Out:
# 0               drug     city                               name  \
# 1  ALBUTEROL SULFATE  Atlanta                 WALMART PHARMACY
# 2  ALBUTEROL SULFATE  Atlanta                  PUBLIX PHARMACY
# 3  ALBUTEROL SULFATE  Atlanta                  KROGER PHARMACY
# 4  ALBUTEROL SULFATE  Atlanta                        WALGREENS
# 5  ALBUTEROL SULFATE  Atlanta  COMMUNITY, A WALGREENS PHARMACY
#
# 0                                            address  price
# 1  835 Martin Luther King Jr Dr NW\nAtlanta, GA 3...   6.76
# 2              905 Memorial Dr SE\nAtlanta, GA 30316   6.78
# 3             800 Glenwood Ave SE\nAtlanta, GA 30316   6.88
# 4              25 Peachtree St SE\nAtlanta, GA 30303   8.83
# 5       565 Peachtree St NE Ste B\nAtlanta, GA 30308   8.83

# %%
with open('rx_spend_by_country.csv', 'r', encoding='utf-8-sig') as f:
    reader = csv.reader(f)
    rx_spend = pd.DataFrame(reader)

rx_spend.columns = rx_spend.iloc[0] #Set column names
rx_spend = rx_spend[1:]
rx_spend['Value'] = pd.to_numeric(rx_spend['Value'])

# %%
# Create barplot of prescription drug spend by country
bar_order = rx_spend.groupby(['Country']).mean().sort_values(by='Value').index
plt.figure(figsize = (25,15))
sns.set(font_scale=1.5)
ax = sns.barplot(x='Country', y='Value', data=rx_spend, order=bar_order, palette='Blues_d')
ax.set(xlabel='Country', ylabel='Per Capita Spend (USD)')

plt.show()

# %%
with open('drug_list.csv','r',encoding='utf-8-sig') as f:
    reader = csv.reader(f)
    drug_list = pd.DataFrame(reader)

drug_list.columns = drug_list.iloc[0]
drug_list = drug_list[1:]
    
drug_list['weight'], drug_list['count'] = pd.to_numeric(drug_list['weight']), pd.to_numeric(drug_list['count'])
drug_list['wellrx_qty'] = pd.to_numeric(drug_list['wellrx_qty'])
drug_list['nadac_unit_price'] = pd.to_numeric(drug_list['nadac_unit_price'])

df = df.merge(drug_list, how='inner', left_on='drug', right_on='drug_name')

df['wellrx_unit_price'] = df['price']/df['wellrx_qty']
df['nadac_savings'] = (df['wellrx_unit_price'] - df['nadac_unit_price'])/df['wellrx_unit_price']
df['adj_wellrx_price'] = df['weight'] * df['wellrx_unit_price']
df['adj_nadac_price'] = df['weight'] * df['nadac_unit_price']

df.head()
# Out:
# 0               drug     city                               name  \
# 0  ALBUTEROL SULFATE  Atlanta                 WALMART PHARMACY
# 1  ALBUTEROL SULFATE  Atlanta                  PUBLIX PHARMACY
# 2  ALBUTEROL SULFATE  Atlanta                  KROGER PHARMACY
# 3  ALBUTEROL SULFATE  Atlanta                        WALGREENS
# 4  ALBUTEROL SULFATE  Atlanta  COMMUNITY, A WALGREENS PHARMACY
#
# 0                                            address  price  \
# 0  835 Martin Luther King Jr Dr NW\nAtlanta, GA 3...   6.76
# 1              905 Memorial Dr SE\nAtlanta, GA 30316   6.78
# 2             800 Glenwood Ave SE\nAtlanta, GA 30316   6.88
# 3              25 Peachtree St SE\nAtlanta, GA 30303   8.83
# 4       565 Peachtree St NE Ste B\nAtlanta, GA 30308   8.83
#
# 0        drug_name_x  wellrx_qty_x  wellrx_dosage_x  nadac_unit_price_x  \
# 0  ALBUTEROL SULFATE           225  2.5 MG/3ML Vial             0.03929
# 1  ALBUTEROL SULFATE           225  2.5 MG/3ML Vial             0.03929
# 2  ALBUTEROL SULFATE           225  2.5 MG/3ML Vial             0.03929
# 3  ALBUTEROL SULFATE           225  2.5 MG/3ML Vial             0.03929
# 4  ALBUTEROL SULFATE           225  2.5 MG/3ML Vial             0.03929
#
# 0  count_x  ...  wellrx_dosage_y  nadac_unit_price_y  count_y  weight_y  \
# 0    47110  ...  2.5 MG/3ML Vial             0.03929    47110  0.034688
# 1    47110  ...  2.5 MG/3ML Vial             0.03929    47110  0.034688
# 2    47110  ...  2.5 MG/3ML Vial             0.03929    47110  0.034688
# 3    47110  ...  2.5 MG/3ML Vial             0.03929    47110  0.034688
# 4    47110  ...  2.5 MG/3ML Vial             0.03929    47110  0.034688
#
# 0          drug_name wellrx_qty    wellrx_dosage nadac_unit_price  count  \
# 0  ALBUTEROL SULFATE        225  2.5 MG/3ML Vial          0.03929  47110
# 1  ALBUTEROL SULFATE        225  2.5 MG/3ML Vial          0.03929  47110
# 2  ALBUTEROL SULFATE        225  2.5 MG/3ML Vial          0.03929  47110
# 3  ALBUTEROL SULFATE        225  2.5 MG/3ML Vial          0.03929  47110
# 4  ALBUTEROL SULFATE        225  2.5 MG/3ML Vial          0.03929  47110
#
# 0    weight
# 0  0.034688
# 1  0.034688
# 2  0.034688
# 3  0.034688
# 4  0.034688
#
# [5 rows x 27 columns]

# %%
from scipy.stats import zscore
df['zscore'] = df.groupby(['drug']).wellrx_unit_price.transform(lambda x : zscore(x))
df['mean_wellrx_unit_price'] = df.groupby(['drug']).wellrx_unit_price.transform(np.mean)
df1 = df.loc[abs(df['zscore']) < 3] # Remove outliers
